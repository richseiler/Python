# %% [markdown]
# # 4.8 Grouping Data and Aggregating Variables

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Folder Path
path = r'C:\Users\Owner\Documents\Instacart Basket Analysis'

# %%
# Import orders_products__merged.plk
df_orders_products_merged = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged_update.pkl'))

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id  order_number  order_dow  \
# 0             19     5.8   3139998      138            28          6
# 1             19     5.8   1977647      138            30          6
# 2             19     5.8    389851      709             2          0
# 3             19     5.8    652770      764             1          3
# 4             19     5.8   1813452      764             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                 11                     3.0                  5          0
# 1                 17                    20.0                  1          1
# 2                 21                     6.0                 20          0
# 3                 13                     NaN                 10          0
# 4                 17                     9.0                 11          1
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly days           Most orders
# 1  Mid-range product  Regularly busy  Regularly days        Average orders
# 2  Mid-range product     Busiest day    Busiest days        Average orders
# 3  Mid-range product  Regularly busy    Slowest days           Most orders
# 4  Mid-range product      Least busy    Slowest days        Average orders

# %%
# Drop unnamed column for df_orders_products_merged

df_orders_products_merged = df_orders_products_merged.drop(columns = ['Unnamed: 0'])

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                     3.0                  5          0  Mid-range product
# 1                    20.0                  1          1  Mid-range product
# 2                     6.0                 20          0  Mid-range product
# 3                     NaN                 10          0  Mid-range product
# 4                     9.0                 11          1  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day
# 0  Regularly busy  Regularly days           Most orders
# 1  Regularly busy  Regularly days        Average orders
# 2     Busiest day    Busiest days        Average orders
# 3  Regularly busy    Slowest days           Most orders
# 4      Least busy    Slowest days        Average orders

# %%
df_orders_products_merged.shape
# Out:
# (32434212, 17)

# %%
# Creating subset

df = df_orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
# 5   1701441      777            16          1                  7
# 6   1871483      825             3          2                 14
# 7   1290456      910            12          3                 10
# 8    369558     1052            10          1                 20
# 9    589712     1052            15          1                 12
#
#    days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                     3.0                  5          0  Mid-range product
# 1                    20.0                  1          1  Mid-range product
# 2                     6.0                 20          0  Mid-range product
# 3                     NaN                 10          0  Mid-range product
# 4                     9.0                 11          1  Mid-range product
# 5                    26.0                  7          0  Mid-range product
# 6                    30.0                  2          0  Mid-range product
# 7                    30.0                  1          0  Mid-range product
# 8                    19.0                  1          0  Mid-range product
# 9                    15.0                  2          1  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day
# 0  Regularly busy  Regularly days           Most orders
# 1  Regularly busy  Regularly days        Average orders
# 2     Busiest day    Busiest days        Average orders
# 3  Regularly busy    Slowest days           Most orders
# 4      Least busy    Slowest days        Average orders
# 5  Regularly busy    Busiest days        Average orders
# 6  Regularly busy  Regularly days           Most orders
# 7  Regularly busy    Slowest days           Most orders
# 8  Regularly busy    Busiest days        Average orders
# 9  Regularly busy    Busiest days           Most orders

# %% [markdown]
# ## Grouping Data with Pandas

# %%
df.groupby('product_name')

# %% [markdown]
#  To recap, you should always use the groupby() function as part of a series of steps, namely, the following:
#
# 1. Split the data into groups based on some criteria.
# 2. Apply a function to each group separately.
# 3. Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.
#
# So far, you’ve only completed the first step—splitting the data into groups (with the group being the “product_name” column)

# %% [markdown]
# ## Aggregating Data with AGG()

# %% [markdown]
#  If you were to calculate the mean of the “order_number” column grouped by the “department_id” column,
#  you could quickly compare the average number of orders across each Instacart department.
#  This will involve two of the steps in the three-step process introduced above:
#
#  1. Split the data into groups based on “department_id.”
#  2. Apply the agg() function to each group to obtain the mean values for the “order_number” column.

# %% [markdown]
# ### Single Aggregation

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %%
# Different way of finding mean of 'order_number'

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.562844
# 2     17.518895
# 3     16.907152
# 4     17.537934
# 5     14.894521
# 6     16.658449
# 7     17.072954
# 8     14.942021
# 9     15.447580
# 10    18.681852
# 11    15.352278
# 12    14.327957
# 13    16.578690
# 14    16.666369
# 15    16.153766
# 16    17.768070
# 17    15.602964
# 18    19.674252
# 19    16.924344
# 20    16.292631
# 21    25.535596
# Name: order_number, dtype: float64

# %% [markdown]
# ### Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.562844   1  99
# 2                17.518895   1  96
# 3                16.907152   1  99
# 4                17.537934   1  99
# 5                14.894521   1  99
# 6                16.658449   1  99
# 7                17.072954   1  99
# 8                14.942021   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.352278   1  99
# 12               14.327957   1  99
# 13               16.578690   1  99
# 14               16.666369   1  99
# 15               16.153766   1  99
# 16               17.768070   1  99
# 17               15.602964   1  99
# 18               19.674252   1  99
# 19               16.924344   1  99
# 20               16.292631   1  99
# 21               25.535596   1  98

# %% [markdown]
# ### Aggregating Data with transform()

# %% [markdown]
# Now, let’s map this task onto the three-step process introduced earlier:
#
# 1. Split the data into groups based on the “user_id” column.
# 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
df_orders_products_merged['max_order'] = df_orders_products_merged.groupby('user_id')['order_number'].transform(np.max)
# df_orders_products_merged['max_order'] = df_orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# Let’s run through each piece of the code in turn:
# First, a new column called “max_order” is created, which will be what stores the maximum order number for each user (step 3).
# Then, the df_orders_products_merged dataframe is grouped by the “user_id” column (step 1).
# And finally, the transform() function is applied on the “order_number” column with the np.max argument (step 2).

# %%
df_orders_products_merged.head(25)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
# 15           1  Chocolate Sandwich Cookies        61             19     5.8
# 16           1  Chocolate Sandwich Cookies        61             19     5.8
# 17           1  Chocolate Sandwich Cookies        61             19     5.8
# 18           1  Chocolate Sandwich Cookies        61             19     5.8
# 19           1  Chocolate Sandwich Cookies        61             19     5.8
# 20           1  Chocolate Sandwich Cookies        61             19     5.8
# 21           1  Chocolate Sandwich Cookies        61             19     5.8
# 22           1  Chocolate Sandwich Cookies        61             19     5.8
# 23           1  Chocolate Sandwich Cookies        61             19     5.8
# 24           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    3139998      138            28          6                 11
# 1    1977647      138            30          6                 17
# 2     389851      709             2          0                 21
# 3     652770      764             1          3                 13
# 4    1813452      764             3          4                 17
# 5    1701441      777            16          1                  7
# 6    1871483      825             3          2                 14
# 7    1290456      910            12          3                 10
# 8     369558     1052            10          1                 20
# 9     589712     1052            15          1                 12
# 10   1798115     1379             1          5                 11
# 11    497193     1480            36          3                 13
# 12   1727826     1480            38          4                 13
# 13   2694698     1480            39          2                 12
# 14   3171753     1494             6          3                 10
# 15    186761     1494             7          2                  8
# 16    317121     1494             9          5                  8
# 17    200390     1540             4          2                  0
# 18    374436     1540             5          1                 21
# 19   2920553     1540             6          1                  0
# 20   2813049     1540             7          2                  2
# 21   2365998     1540             8          1                 23
# 22   1604797     1540             9          1                  3
# 23   2799665     1540            14          1                 14
# 24   2228851     1540            15          1                 14
#
#     days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                      3.0                  5          0  Mid-range product
# 1                     20.0                  1          1  Mid-range product
# 2                      6.0                 20          0  Mid-range product
# 3                      NaN                 10          0  Mid-range product
# 4                      9.0                 11          1  Mid-range product
# 5                     26.0                  7          0  Mid-range product
# 6                     30.0                  2          0  Mid-range product
# 7                     30.0                  1          0  Mid-range product
# 8                     19.0                  1          0  Mid-range product
# 9                     15.0                  2          1  Mid-range product
# 10                     NaN                  1          0  Mid-range product
# 11                     7.0                  1          0  Mid-range product
# 12                     7.0                  3          1  Mid-range product
# 13                    12.0                  4          1  Mid-range product
# 14                     2.0                  8          0  Mid-range product
# 15                     6.0                 18          1  Mid-range product
# 16                    10.0                 12          1  Mid-range product
# 17                     7.0                 10          0  Mid-range product
# 18                     6.0                  9          1  Mid-range product
# 19                    14.0                  9          1  Mid-range product
# 20                     8.0                  7          1  Mid-range product
# 21                     6.0                  6          1  Mid-range product
# 22                    28.0                  6          1  Mid-range product
# 23                     7.0                 10          1  Mid-range product
# 24                     7.0                  3          1  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day  max_order
# 0   Regularly busy  Regularly days           Most orders         32
# 1   Regularly busy  Regularly days        Average orders         32
# 2      Busiest day    Busiest days        Average orders          5
# 3   Regularly busy    Slowest days           Most orders          3
# 4       Least busy    Slowest days        Average orders          3
# 5   Regularly busy    Busiest days        Average orders         26
# 6   Regularly busy  Regularly days           Most orders          9
# 7   Regularly busy    Slowest days           Most orders         12
# 8   Regularly busy    Busiest days        Average orders         20
# 9   Regularly busy    Busiest days           Most orders         20
# 10  Regularly busy  Regularly days           Most orders         10
# 11  Regularly busy    Slowest days           Most orders         43
# 12      Least busy    Slowest days           Most orders         43
# 13  Regularly busy  Regularly days           Most orders         43
# 14  Regularly busy    Slowest days           Most orders         13
# 15  Regularly busy  Regularly days        Average orders         13
# 16  Regularly busy  Regularly days        Average orders         13
# 17  Regularly busy  Regularly days         Fewest orders         28
# 18  Regularly busy    Busiest days        Average orders         28
# 19  Regularly busy    Busiest days         Fewest orders         28
# 20  Regularly busy  Regularly days         Fewest orders         28
# 21  Regularly busy    Busiest days        Average orders         28
# 22  Regularly busy    Busiest days         Fewest orders         28
# 23  Regularly busy    Busiest days           Most orders         28
# 24  Regularly busy    Busiest days           Most orders         28

# %% [markdown]
# ### Deriving Columns with loc()

# %% [markdown]
# To create your flag, you’ll need some criteria. You can use the following:
#
# 1. If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# 2. If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# 3. If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['max_order'] <= 40) & (df_orders_products_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_orders_products_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                     3.0                  5          0  Mid-range product
# 1                    20.0                  1          1  Mid-range product
# 2                     6.0                 20          0  Mid-range product
# 3                     NaN                 10          0  Mid-range product
# 4                     9.0                 11          1  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day  max_order  \
# 0  Regularly busy  Regularly days           Most orders         32
# 1  Regularly busy  Regularly days        Average orders         32
# 2     Busiest day    Busiest days        Average orders          5
# 3  Regularly busy    Slowest days           Most orders          3
# 4      Least busy    Slowest days        Average orders          3
#
#        loyalty_flag
# 0  Regular customer
# 1  Regular customer
# 2      New customer
# 3      New customer
# 4      New customer

# %% [markdown]
# You learned already that to access a single column in a dataframe, you can index it like so: df['column']

# %%
# check the accuracy of the 'loyalty_flag' column with output from columns 'user_id', 'max_order', and 'loyalty_flag' column

df_orders_products_merged[['user_id', 'max_order', 'loyalty_flag']].sample(30)

# The first set of brackets is the same as the brackets used in df['column'] above,
# while the second set of brackets is indicating that what you’re indexing is a list of multiple columns (and lists are always included within brackets).
# This is why there are two sets of brackets.
# Out:
#           user_id  max_order      loyalty_flag
# 209892      94973         67    Loyal customer
# 14062897    98918         22  Regular customer
# 8726835    134348         11  Regular customer
# 11476586   145093         26  Regular customer
# 24807008   163554         14  Regular customer
# 1985760    132089          6      New customer
# 12751528   153180         32  Regular customer
# 10316614   195624         44    Loyal customer
# 4196040    136067          4      New customer
# 20633579   191936          4      New customer
# 28543147    69050         16  Regular customer
# 12200385   151031         10      New customer
# 25166368    25668         11  Regular customer
# 5477465     72170          3      New customer
# 2033461     15648         54    Loyal customer
# 18244465    44795         36  Regular customer
# 26548070    51495         22  Regular customer
# 7211604    192083         43    Loyal customer
# 840321     202781         24  Regular customer
# 15791894   144993         59    Loyal customer
# 9219824    150011         35  Regular customer
# 22062068     5095         45    Loyal customer
# 26116515    24618         26  Regular customer
# 10957920    71152         23  Regular customer
# 21567256     7318          3      New customer
# 27482525   182364         99    Loyal customer
# 9890222    102573         50    Loyal customer
# 29211753   191408          9      New customer
# 19706960   201430         26  Regular customer
# 8070027    180075         75    Loyal customer

# %% [markdown]
# And that brings you to the end of the three-step process!
# 1. You started by grouping your data,
# 2. followed up by applying an aggregation function,
# 3. and finished everything off by using the resulting aggregation to create a flag column

# %% [markdown]
# # Task 4.8

# %% [markdown]
# ### Step 1

# %% [markdown]
# Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %% [markdown]
# ### Step 2

# %% [markdown]
# In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
df_orders_products_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Step 3

# %% [markdown]
# Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %%
# Below are the subset results from earlier

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %% [markdown]
# Answer: The average of an order number doesn't represent numerical data, it is more representative of categorical data because it is not a measurement of something.

# %% [markdown]
# ### Step 4

# %% [markdown]
# Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#Split the data into groups based on the 'user_id' column. Apply the transform() function on the 'order_number' column to generate the max orders for each user.
df_orders_products_merged['max_order'] = df_orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['max_order'] <= 40) & (df_orders_products_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_orders_products_merged.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    3139998      138            28          6                 11
# 1    1977647      138            30          6                 17
# 2     389851      709             2          0                 21
# 3     652770      764             1          3                 13
# 4    1813452      764             3          4                 17
# 5    1701441      777            16          1                  7
# 6    1871483      825             3          2                 14
# 7    1290456      910            12          3                 10
# 8     369558     1052            10          1                 20
# 9     589712     1052            15          1                 12
# 10   1798115     1379             1          5                 11
# 11    497193     1480            36          3                 13
# 12   1727826     1480            38          4                 13
# 13   2694698     1480            39          2                 12
# 14   3171753     1494             6          3                 10
#
#     days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                      3.0                  5          0  Mid-range product
# 1                     20.0                  1          1  Mid-range product
# 2                      6.0                 20          0  Mid-range product
# 3                      NaN                 10          0  Mid-range product
# 4                      9.0                 11          1  Mid-range product
# 5                     26.0                  7          0  Mid-range product
# 6                     30.0                  2          0  Mid-range product
# 7                     30.0                  1          0  Mid-range product
# 8                     19.0                  1          0  Mid-range product
# 9                     15.0                  2          1  Mid-range product
# 10                     NaN                  1          0  Mid-range product
# 11                     7.0                  1          0  Mid-range product
# 12                     7.0                  3          1  Mid-range product
# 13                    12.0                  4          1  Mid-range product
# 14                     2.0                  8          0  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day  max_order  \
# 0   Regularly busy  Regularly days           Most orders         32
# 1   Regularly busy  Regularly days        Average orders         32
# 2      Busiest day    Busiest days        Average orders          5
# 3   Regularly busy    Slowest days           Most orders          3
# 4       Least busy    Slowest days        Average orders          3
# 5   Regularly busy    Busiest days        Average orders         26
# 6   Regularly busy  Regularly days           Most orders          9
# 7   Regularly busy    Slowest days           Most orders         12
# 8   Regularly busy    Busiest days        Average orders         20
# 9   Regularly busy    Busiest days           Most orders         20
# 10  Regularly busy  Regularly days           Most orders         10
# 11  Regularly busy    Slowest days           Most orders         43
# 12      Least busy    Slowest days           Most orders         43
# 13  Regularly busy  Regularly days           Most orders         43
# 14  Regularly busy    Slowest days           Most orders         13
#
#         loyalty_flag
# 0   Regular customer
# 1   Regular customer
# 2       New customer
# 3       New customer
# 4       New customer
# 5   Regular customer
# 6       New customer
# 7   Regular customer
# 8   Regular customer
# 9   Regular customer
# 10      New customer
# 11    Loyal customer
# 12    Loyal customer
# 13    Loyal customer
# 14  Regular customer

# %%
#Checking the count of 'loyalty_flag' values
df_orders_products_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
df_orders_products_merged['loyalty_flag'].value_counts(dropna = False).sum()
# Out:
# 32434212

# %%
df_orders_products_merged.shape
# Out:
# (32434212, 19)

# %% [markdown]
# Answer: The sum of the count of loyalty flags is equal to the total number of rows in "df_orders_products_merged"

# %% [markdown]
# ### Step 5

# %% [markdown]
# The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
print('The mean, min, max, and sum of prices grouped by the loyalty_flag column in df_orders_products_merged:')
df_orders_products_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max','sum']})
# Out:
# The mean, min and max of prices grouped by the loyalty_flag column in df_orders_products_merged:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.388747  1.0  99999.0  106939028.9
# New customer      13.294370  1.0  99999.0   83081810.0
# Regular customer  12.496203  1.0  99999.0  198578123.1

# %% [markdown]
# Answer: I was surprised to find that the average prices for loyal customers is the lowest, and the averaage prices for new customers is the highest. This would be interesting to find out why.
#
# I was also surprised by the maximum price being $9,999 for all three groups of customers. I would like to do some more research to find out what they're buying that is that expensive.

# %%
# Run descriptive statistics on the 'prices' column

print('Descriptive statistics of the prices column:')
df_orders_products_merged['prices'].describe()
# Out:
# Descriptive statistics of the prices column:
# count    3.243421e+07
# mean     1.198114e+01
# std      4.954311e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %% [markdown]
# ### Step 6

# %% [markdown]
# The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying.
#
# Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Creating “average_price” column using transform()

df_orders_products_merged['average_price'] = df_orders_products_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  ...  \
# 0   3139998      138            28          6                 11  ...
# 1   1977647      138            30          6                 17  ...
# 2    389851      709             2          0                 21  ...
# 3    652770      764             1          3                 13  ...
# 4   1813452      764             3          4                 17  ...
#
#    add_to_cart_order  reordered    price_range_loc     busiest_day  \
# 0                  5          0  Mid-range product  Regularly busy
# 1                  1          1  Mid-range product  Regularly busy
# 2                 20          0  Mid-range product     Busiest day
# 3                 10          0  Mid-range product  Regularly busy
# 4                 11          1  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order      loyalty_flag avg_price  \
# 0  Regularly days           Most orders        32  Regular customer  6.935811
# 1  Regularly days        Average orders        32  Regular customer  6.935811
# 2    Busiest days        Average orders         5      New customer  7.930208
# 3    Slowest days           Most orders         3      New customer  4.972414
# 4    Slowest days        Average orders         3      New customer  4.972414
#
#    average_price
# 0       6.935811
# 1       6.935811
# 2       7.930208
# 3       4.972414
# 4       4.972414
#
# [5 rows x 21 columns]

# %%
# Rounding averages 

df_orders_products_merged['average_price'] = df_orders_products_merged['average_price'].round(2)

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  ...  \
# 0   3139998      138            28          6                 11  ...
# 1   1977647      138            30          6                 17  ...
# 2    389851      709             2          0                 21  ...
# 3    652770      764             1          3                 13  ...
# 4   1813452      764             3          4                 17  ...
#
#    add_to_cart_order  reordered    price_range_loc     busiest_day  \
# 0                  5          0  Mid-range product  Regularly busy
# 1                  1          1  Mid-range product  Regularly busy
# 2                 20          0  Mid-range product     Busiest day
# 3                 10          0  Mid-range product  Regularly busy
# 4                 11          1  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order      loyalty_flag avg_price  \
# 0  Regularly days           Most orders        32  Regular customer  6.935811
# 1  Regularly days        Average orders        32  Regular customer  6.935811
# 2    Busiest days        Average orders         5      New customer  7.930208
# 3    Slowest days           Most orders         3      New customer  4.972414
# 4    Slowest days        Average orders         3      New customer  4.972414
#
#    average_price
# 0           6.94
# 1           6.94
# 2           7.93
# 3           4.97
# 4           4.97
#
# [5 rows x 21 columns]

# %%
# Drop avg_price column for df_orders_products_merged

df_orders_products_merged = df_orders_products_merged.drop(columns = ['avg_price'])

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                     3.0                  5          0  Mid-range product
# 1                    20.0                  1          1  Mid-range product
# 2                     6.0                 20          0  Mid-range product
# 3                     NaN                 10          0  Mid-range product
# 4                     9.0                 11          1  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day  max_order  \
# 0  Regularly busy  Regularly days           Most orders         32
# 1  Regularly busy  Regularly days        Average orders         32
# 2     Busiest day    Busiest days        Average orders          5
# 3  Regularly busy    Slowest days           Most orders          3
# 4      Least busy    Slowest days        Average orders          3
#
#        loyalty_flag  average_price
# 0  Regular customer           6.94
# 1  Regular customer           6.94
# 2      New customer           7.93
# 3      New customer           4.97
# 4      New customer           4.97

# %%
# Creating a 'spending_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Creating a 'spending_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  ...  \
# 0   3139998      138            28          6                 11  ...
# 1   1977647      138            30          6                 17  ...
# 2    389851      709             2          0                 21  ...
# 3    652770      764             1          3                 13  ...
# 4   1813452      764             3          4                 17  ...
#
#    add_to_cart_order  reordered    price_range_loc     busiest_day  \
# 0                  5          0  Mid-range product  Regularly busy
# 1                  1          1  Mid-range product  Regularly busy
# 2                 20          0  Mid-range product     Busiest day
# 3                 10          0  Mid-range product  Regularly busy
# 4                 11          1  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0  Regularly days           Most orders        32  Regular customer
# 1  Regularly days        Average orders        32  Regular customer
# 2    Busiest days        Average orders         5      New customer
# 3    Slowest days           Most orders         3      New customer
# 4    Slowest days        Average orders         3      New customer
#
#   average_price  spending_flag
# 0          6.94    Low spender
# 1          6.94    Low spender
# 2          7.93    Low spender
# 3          4.97    Low spender
# 4          4.97    Low spender
#
# [5 rows x 21 columns]

# %%
# Check the frequency

df_orders_products_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31798102
# High spender      636110
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Step 7

# %% [markdown]
# In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers.
#
# Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
#
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
#
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
#
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Creating “median_prior_orders” column using transform()

df_orders_products_merged['median_prior_orders'] = df_orders_products_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  ...  \
# 0   3139998      138            28          6                 11  ...
# 1   1977647      138            30          6                 17  ...
# 2    389851      709             2          0                 21  ...
# 3    652770      764             1          3                 13  ...
# 4   1813452      764             3          4                 17  ...
#
#    reordered    price_range_loc     busiest_day    busiest_days  \
# 0          0  Mid-range product  Regularly busy  Regularly days
# 1          1  Mid-range product  Regularly busy  Regularly days
# 2          0  Mid-range product     Busiest day    Busiest days
# 3          0  Mid-range product  Regularly busy    Slowest days
# 4          1  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day max_order      loyalty_flag  average_price  \
# 0           Most orders        32  Regular customer           6.94
# 1        Average orders        32  Regular customer           6.94
# 2        Average orders         5      New customer           7.93
# 3           Most orders         3      New customer           4.97
# 4        Average orders         3      New customer           4.97
#
#   spending_flag  median_prior_orders
# 0   Low spender                  8.0
# 1   Low spender                  8.0
# 2   Low spender                  8.0
# 3   Low spender                  9.0
# 4   Low spender                  9.0
#
# [5 rows x 22 columns]

# %%
# Creating a 'order_frequency_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['median_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Creating a 'order_frequency_flag' flag

df_orders_products_merged.loc[(df_orders_products_merged['median_prior_orders'] > 10) & (df_orders_products_merged['median_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Creating a 'order_frequency_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['median_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df_orders_products_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  ...  \
# 0   3139998      138            28          6                 11  ...
# 1   1977647      138            30          6                 17  ...
# 2    389851      709             2          0                 21  ...
# 3    652770      764             1          3                 13  ...
# 4   1813452      764             3          4                 17  ...
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly days           Most orders
# 1  Mid-range product  Regularly busy  Regularly days        Average orders
# 2  Mid-range product     Busiest day    Busiest days        Average orders
# 3  Mid-range product  Regularly busy    Slowest days           Most orders
# 4  Mid-range product      Least busy    Slowest days        Average orders
#
#   max_order      loyalty_flag average_price  spending_flag  \
# 0        32  Regular customer          6.94    Low spender
# 1        32  Regular customer          6.94    Low spender
# 2         5      New customer          7.93    Low spender
# 3         3      New customer          4.97    Low spender
# 4         3      New customer          4.97    Low spender
#
#   median_prior_orders  order_frequency_flag
# 0                 8.0     Frequent customer
# 1                 8.0     Frequent customer
# 2                 8.0     Frequent customer
# 3                 9.0     Frequent customer
# 4                 9.0     Frequent customer
#
# [5 rows x 23 columns]

# %%
# Check the frequency

df_orders_products_merged['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21577409
# Regular customer          7217134
# Non-frequent customer     3639669
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# # Step 9

# %% [markdown]
# Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_orders_products_merged_updated_2.pkl'))
